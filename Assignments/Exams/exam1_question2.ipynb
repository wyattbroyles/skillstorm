# %%
import pandas as pd

df = pd.read_csv("songs_normalize.csv")
df.head(20)
# Out:
#              artist                                              song  \
# 0    Britney Spears                            Oops!...I Did It Again
# 1         blink-182                              All The Small Things
# 2        Faith Hill                                           Breathe
# 3          Bon Jovi                                      It's My Life
# 4            *NSYNC                                       Bye Bye Bye
# 5             Sisqo                                        Thong Song
# 6            Eminem                               The Real Slim Shady
# 7   Robbie Williams                                           Rock DJ
# 8   Destiny's Child                                       Say My Name
# 9             Modjo                            Lady - Hear Me Tonight
# 10  Gigi D'Agostino                                  L'Amour Toujours
# 11        Eiffel 65  Move Your Body - Gabry Ponte Original Radio Edit
# ...

# %%
df.nunique() # number of records and unique genres
# Out:
# artist               835
# song                1879
# duration_ms         1793
# explicit               2
# year                  23
# popularity            76
# danceability         565
# energy               580
# key                   12
# loudness            1671
# mode                   2
# speechiness          837
# acousticness        1208
# instrumentalness     772
# liveness             783
# valence              760
# tempo               1831
# genre                 59
# dtype: int64

# %%
oldest_song = df['year'].min()
print(oldest_song)
# Out:
# 1998

# %%
most_popular = df['popularity'].max()
print(most_popular)
# Out:
# 89

# %%
df1 = df['genre']
df1.head()
# Out:
# 0             pop
# 1       rock, pop
# 2    pop, country
# 3     rock, metal
# 4             pop
# Name: genre, dtype: object

# %%
df1.explode()
df1.nunique()
# Out:
# 59

# %%
df1 = df1.dropna() #drop any row that has a null value

df1.reset_index(drop=True,inplace=True)
df1.head()
# Out:
# 0             pop
# 1       rock, pop
# 2    pop, country
# 3     rock, metal
# 4             pop
# Name: genre, dtype: object

# %%
genre_datatype = type(df['genre'])
print(genre_datatype)
# Out:
# <class 'pandas.core.series.Series'>

# %%
unique_genres = df["genre"].unique()
for genre in unique_genres:
    print()

# %%
songs = (df['song'])

max = 0
for song in songs:
    char_count = 0
    for char in song:
        char_count+=1
if char_count > max:
    max = song
        
print(max)
# Out:
# Circles

# %%
total_ms = df["duration_ms"].sum()
print(f"{total_ms} ms")
# Out:
# 457496249 ms

# %%
popular_explicit = df[df['explicit'] == True]
df_sorted = popular_explicit.sort_values(by= 'popularity', ascending=False)
df_sorted.head(2)
# Out:
#          artist          song  duration_ms  explicit  year  popularity  \
# 1311  Tom Odell  Another Love       244360      True  2013          88
# 201      Eminem    Without Me       290320      True  2002          87
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1311         0.445   0.537    4    -8.532     0       0.0400       0.69500
# 201          0.908   0.669    7    -2.827     1       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo    genre
# 1311          0.000017    0.0944    0.131  122.769      pop
# 201           0.000000    0.2370    0.662  112.238  hip hop

# %%
df = pd.read_csv("songs_normalize.csv") #250KB
df.to_parquet("spotify_songs.parquet") #151KB
# Out:
# 192
